# %% [markdown]
# ---
# title: "MD"
# format:
#   html:
#     toc: true
#     css: styles.css
#     echo: false
# jupyter: python3
# execute:
#   echo: false # Hides all code globally
# ---

# %%
from util import Skim
from config import scenarioPath_OpenPath
from config import scenarioPath_EMME437
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
# Suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# generate comparison
scenarioOne = Skim.skimReader(scenarioPath_OpenPath, time_periods='MD',skim='transit')
scenarioTwo = Skim.skimReader(scenarioPath_EMME437, time_periods='MD',skim='transit')


# OpenPaths minus EMME4.3.7 (exclude Origin and Destination columns)
comparison = scenarioOne.set_index(['Origin', 'Destination']) - scenarioTwo.set_index(['Origin','Destination'])
comparison.reset_index(inplace=True)

# %% [markdown]
# # Scatterplot Comparison of MD Peak for WALK PRM modes assignment

# %% [markdown]
# Scatterplot comparison of MD Peak total actual in-vehicle travel time by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_TOTALIVTT__MD'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_TOTALIVTT__MD']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_TOTALIVTT__MD")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0006
# Slope: 0.9991
# R² Score: 0.9997
# RMSE: 0.4146

# %% [markdown]
# Scatterplot comparison of MD Peak actual in-vehicle travel time on LRT mode by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_LRTIVTT__MD'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_LRTIVTT__MD']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_LRTIVTT__MD")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0033
# Slope: 0.9969
# R² Score: 0.9981
# RMSE: 0.5535

# %% [markdown]
# Scatterplot comparison of MD Peak actual in-vehicle travel time on commuter rail mode by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_CMRIVTT__MD'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_CMRIVTT__MD']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_CMRIVTT__MD")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0004
# Slope: 0.9998
# R² Score: 0.9995
# RMSE: 0.1737

# %% [markdown]
# Scatterplot comparison of MD Peak actual in-vehicle travel time on express bus mode by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_EXPIVTT__MD'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_EXPIVTT__MD']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_EXPIVTT__MD")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0051
# Slope: 0.9887
# R² Score: 0.9966
# RMSE: 0.3215

# %% [markdown]
# Scatterplot comparison of MD Peak actual in-vehicle travel time on BRT mode by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_BRTIVTT__MD'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_BRTIVTT__MD']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_BRTIVTT__MD")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0028
# Slope: 1.0015
# R² Score: 0.9991
# RMSE: 0.3914

# %% [markdown]
# # Summary of transit MD skim comparison (EMME OpenPath - EMME 4.3.7)

# %% [markdown]
# To display the top 5 rows of skim comparison (sort by WALK_PRM_TOTALIVTT__MD)

# %%
comparison.sort_values(by='WALK_PRM_TOTALIVTT__MD', ascending=False).head()
# Out:
#          Origin  Destination  WALK_PRM_TOTALIVTT__MD  WALK_PRM_LRTIVTT__MD  \
# 8800773    1780           61                   48.65                 42.12
# 8380278    1695           61                   48.65                 42.12
# 9335049    1888           61                   48.65                 42.12
# 7450239    1507           58                   48.33                 41.80
# 7450254    1507           73                   48.33                 41.80
#
#          WALK_PRM_CMRIVTT__MD  WALK_PRM_EXPIVTT__MD  WALK_PRM_LTDEXPIVTT__MD  \
# 8800773                -51.85                 23.49                     0.00
# 8380278                -51.85                 23.49                     0.00
# 9335049                -51.85                 23.49                     0.00
# 7450239                -51.85                 23.49                     0.00
# 7450254                -51.85                 23.49                     0.00
#
#          WALK_PRM_BRTIVTT__MD
# 8800773                 34.89
# 8380278                 34.89
# 9335049                 34.89
# 7450239                 34.89
# 7450254                 34.89

# %% [markdown]
# Below is the summary of select matrices difference in transit MD skim

# %%
comparison.WALK_PRM_TOTALIVTT__MD.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.42
# min          -57.78
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           48.65
# Name: WALK_PRM_TOTALIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_LRTIVTT__MD.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.55
# min          -53.38
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           49.24
# Name: WALK_PRM_LRTIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_CMRIVTT__MD.describe()
# Out:
# count   24472809.00
# mean          -0.00
# std            0.17
# min          -58.13
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           58.44
# Name: WALK_PRM_CMRIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_EXPIVTT__MD.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.33
# min          -59.79
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           52.49
# Name: WALK_PRM_EXPIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_LTDEXPIVTT__MD.describe()
# Out:
# count   24472809.00
# mean           0.00
# std            0.00
# min            0.00
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max            0.00
# Name: WALK_PRM_LTDEXPIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_BRTIVTT__MD.describe()
# Out:
# count   24472809.00
# mean          -0.01
# std            0.39
# min          -45.89
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           59.55
# Name: WALK_PRM_BRTIVTT__MD, dtype: float64

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__MD greater than 40

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__MD']>40]
# Out:
#          Origin  Destination  WALK_PRM_TOTALIVTT__MD  WALK_PRM_LRTIVTT__MD  \
# 294413       60         2541                   15.05                 49.24
# 339160       69         2765                   11.99                 49.24
# 7450239    1507           58                   48.33                 41.80
# 7450244    1507           63                   48.33                 41.80
# 7450248    1507           67                   48.33                 41.80
# 7450254    1507           73                   48.33                 41.80
# 8380278    1695           61                   48.65                 42.12
# 8800773    1780           61                   48.65                 42.12
# 9335049    1888           61                   48.65                 42.12
#
#          WALK_PRM_CMRIVTT__MD  WALK_PRM_EXPIVTT__MD  WALK_PRM_LTDEXPIVTT__MD  \
# 294413                 -51.38                -28.20                     0.00
# 339160                 -49.33                -33.30                     0.00
# 7450239                -51.85                 23.49                     0.00
# 7450244                -51.85                 23.49                     0.00
# 7450248                -51.85                 23.49                     0.00
# 7450254                -51.85                 23.49                     0.00
# 8380278                -51.85                 23.49                     0.00
# 8800773                -51.85                 23.49                     0.00
# 9335049                -51.85                 23.49                     0.00
#
#          WALK_PRM_BRTIVTT__MD
# 294413                  45.38
# 339160                  45.38
# 7450239                 34.89
# 7450244                 34.89
# 7450248                 34.89
# 7450254                 34.89
# 8380278                 34.89
# 8800773                 34.89
# 9335049                 34.89

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__MD less than -50

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__MD']<-50]
# Out:
#           Origin  Destination  WALK_PRM_TOTALIVTT__MD  WALK_PRM_LRTIVTT__MD  \
# 12407314    2509          239                  -57.78                -53.38
# 12407327    2509          252                  -57.78                -53.38
# 12407328    2509          253                  -57.78                -53.38
# 12407336    2509          261                  -57.78                -53.38
# 12407338    2509          263                  -57.78                -53.38
# ...          ...          ...                     ...                   ...
# 14697558    2972           22                  -16.83                -53.38
# 14786604    2990           22                  -16.83                -53.38
# 15058689    3045           22                  -16.83                -53.38
# 15078477    3049           22                  -16.83                -53.38
# 15548442    3144           22                  -16.83                -53.38
#
#           WALK_PRM_CMRIVTT__MD  WALK_PRM_EXPIVTT__MD  WALK_PRM_LTDEXPIVTT__MD  \
# 12407314                 25.66                  0.00                     0.00
# 12407327                 25.66                  0.00                     0.00
# 12407328                 25.66                  0.00                     0.00
# 12407336                 25.66                  0.00                     0.00
# 12407338                 25.66                  0.00                     0.00
# ...                        ...                   ...                      ...
# 14697558                 58.44                  0.00                     0.00
# 14786604                 58.44                  0.00                     0.00
# 15058689                 58.44                  0.00                     0.00
# 15078477                 58.44                  0.00                     0.00
# 15548442                 58.44                  0.00                     0.00
#
#           WALK_PRM_BRTIVTT__MD
# 12407314                -30.06
# 12407327                -30.06
# 12407328                -30.06
# 12407336                -30.06
# 12407338                -30.06
# ...                        ...
# 14697558                -21.90
# 14786604                -21.90
# 15058689                -21.90
# 15078477                -21.90
# 15548442                -21.90
#
# [151 rows x 8 columns]
