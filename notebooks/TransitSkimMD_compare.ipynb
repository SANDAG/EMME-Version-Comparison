# %% [markdown]
# ---
# title: "MD"
# format:
#   html:
#     toc: true
#     css: styles.css
#     echo: false
# jupyter: python3
# execute:
#   echo: false # Hides all code globally
# ---

# %%
from util import Skim
from config import scenarioPath_OpenPath
from config import scenarioPath_EMME437
import pandas as pd

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
# Suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# generate comparison
comparison = Skim.comparison(scenarioPath_OpenPath, scenarioPath_EMME437, 'MD', 'transit')

# %% [markdown]
# # Scatterplot Comparison of MD Peak for WALK PRM modes assignment

# %% [markdown]
# Scatterplot comparison of MD Peak total actual in-vehicle travel time by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_TOTALIVTT__MD', scenarioPath_OpenPath, scenarioPath_EMME437, 'MD', 'transit')
# Out:
# Intercept: 0.0006
# Slope: 0.9991
# R² Score: 0.9997
# RMSE: 0.4146

# %% [markdown]
# Scatterplot comparison of MD Peak actual in-vehicle travel time on LRT mode by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_LRTIVTT__MD', scenarioPath_OpenPath, scenarioPath_EMME437, 'MD', 'transit')
# Out:
# Intercept: 0.0033
# Slope: 0.9969
# R² Score: 0.9981
# RMSE: 0.5535

# %% [markdown]
# Scatterplot comparison of MD Peak actual in-vehicle travel time on commuter rail mode by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_CMRIVTT__MD', scenarioPath_OpenPath, scenarioPath_EMME437, 'MD', 'transit')
# Out:
# Intercept: 0.0004
# Slope: 0.9998
# R² Score: 0.9995
# RMSE: 0.1737

# %% [markdown]
# Scatterplot comparison of MD Peak actual in-vehicle travel time on express bus mode by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_EXPIVTT__MD', scenarioPath_OpenPath, scenarioPath_EMME437, 'MD', 'transit')
# Out:
# Intercept: 0.0051
# Slope: 0.9887
# R² Score: 0.9966
# RMSE: 0.3215

# %% [markdown]
# Scatterplot comparison of MD Peak actual in-vehicle travel time on BRT mode by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_BRTIVTT__MD', scenarioPath_OpenPath, scenarioPath_EMME437, 'MD', 'transit')
# Out:
# Intercept: 0.0028
# Slope: 1.0015
# R² Score: 0.9991
# RMSE: 0.3914

# %% [markdown]
# # Summary of transit MD skim comparison (EMME OpenPath - EMME 4.3.7)

# %% [markdown]
# To display the top 5 rows of skim comparison (sort by WALK_PRM_TOTALIVTT__MD)

# %%
comparison.sort_values(by='WALK_PRM_TOTALIVTT__MD', ascending=False).head().style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'blue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_50a48 thead th {
#   background-color: blue;
# }
# </style>
# <table id="T_50a48">
#   <thead>
#     <tr>
#       <th id="T_50a48_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_50a48_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_50a48_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__MD</th>
#       <th id="T_50a48_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__MD</th>
#       <th id="T_50a48_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__MD</th>
#       <th id="T_50a48_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__MD</th>
#       <th id="T_50a48_level0_col6" class="col_heading level0 col6" >WALK_PRM_LTDEXPIVTT__MD</th>
#       <th id="T_50a48_level0_col7" class="col_heading level0 col7" >WALK_PRM_BRTIVTT__MD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# Below is the summary of select matrices difference in transit MD skim

# %%
comparison.WALK_PRM_TOTALIVTT__MD.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.42
# min          -57.78
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           48.65
# Name: WALK_PRM_TOTALIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_LRTIVTT__MD.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.55
# min          -53.38
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           49.24
# Name: WALK_PRM_LRTIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_CMRIVTT__MD.describe()
# Out:
# count   24472809.00
# mean          -0.00
# std            0.17
# min          -58.13
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           58.44
# Name: WALK_PRM_CMRIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_EXPIVTT__MD.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.33
# min          -59.79
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           52.49
# Name: WALK_PRM_EXPIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_LTDEXPIVTT__MD.describe()
# Out:
# count   24472809.00
# mean           0.00
# std            0.00
# min            0.00
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max            0.00
# Name: WALK_PRM_LTDEXPIVTT__MD, dtype: float64

# %%
comparison.WALK_PRM_BRTIVTT__MD.describe()
# Out:
# count   24472809.00
# mean          -0.01
# std            0.39
# min          -45.89
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           59.55
# Name: WALK_PRM_BRTIVTT__MD, dtype: float64

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__MD greater than 40

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__MD']>40].style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'blue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_ff07d thead th {
#   background-color: blue;
# }
# </style>
# <table id="T_ff07d">
#   <thead>
#     <tr>
#       <th id="T_ff07d_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_ff07d_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_ff07d_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__MD</th>
#       <th id="T_ff07d_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__MD</th>
#       <th id="T_ff07d_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__MD</th>
#       <th id="T_ff07d_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__MD</th>
#       <th id="T_ff07d_level0_col6" class="col_heading level0 col6" >WALK_PRM_LTDEXPIVTT__MD</th>
#       <th id="T_ff07d_level0_col7" class="col_heading level0 col7" >WALK_PRM_BRTIVTT__MD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__MD less than -50

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__MD']<-50].style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'blue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_b9463 thead th {
#   background-color: blue;
# }
# </style>
# <table id="T_b9463">
#   <thead>
#     <tr>
#       <th id="T_b9463_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_b9463_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_b9463_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__MD</th>
#       <th id="T_b9463_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__MD</th>
#       <th id="T_b9463_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__MD</th>
#       <th id="T_b9463_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__MD</th>
#       <th id="T_b9463_level0_col6" class="col_heading level0 col6" >WALK_PRM_LTDEXPIVTT__MD</th>
#       <th id="T_b9463_level0_col7" class="col_heading level0 col7" >WALK_PRM_BRTIVTT__MD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
