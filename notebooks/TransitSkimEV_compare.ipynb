# %% [markdown]
# ---
# title: "EV"
# format:
#   html:
#     toc: true
#     css: styles.css
#     echo: false
# jupyter: python3
# execute:
#   echo: false # Hides all code globally
# ---

# %%
from util import Skim
from config import scenarioPath_OpenPath
from config import scenarioPath_EMME437
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
# Suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# generate comparison
scenarioOne = Skim.skimReader(scenarioPath_OpenPath, time_periods='EV',skim='transit')
scenarioTwo = Skim.skimReader(scenarioPath_EMME437, time_periods='EV',skim='transit')


# OpenPaths minus EMME4.3.7 (exclude Origin and Destination columns)
comparison = scenarioOne.set_index(['Origin', 'Destination']) - scenarioTwo.set_index(['Origin','Destination'])
comparison.reset_index(inplace=True)

# %% [markdown]
# # Scatterplot Comparison of EV Peak for WALK PRM modes assignment

# %% [markdown]
# Scatterplot comparison of EV Peak total actual in-vehicle travel time by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_TOTALIVTT__EV'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_TOTALIVTT__EV']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_TOTALIVTT__EV")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0041
# Slope: 0.9991
# R² Score: 0.9996
# RMSE: 0.5382

# %% [markdown]
# Scatterplot comparison of EV Peak actual in-vehicle travel time on LRT mode by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_LRTIVTT__EV'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_LRTIVTT__EV']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_LRTIVTT__EV")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0037
# Slope: 0.9983
# R² Score: 0.9988
# RMSE: 0.4782

# %% [markdown]
# Scatterplot comparison of EV Peak actual in-vehicle travel time on commuter rail mode by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_CMRIVTT__EV'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_CMRIVTT__EV']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_CMRIVTT__EV")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0033
# Slope: 1.0000
# R² Score: 0.9971
# RMSE: 0.3731

# %% [markdown]
# Scatterplot comparison of EV Peak actual in-vehicle travel time on express bus mode by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_EXPIVTT__EV'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_EXPIVTT__EV']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_EXPIVTT__EV")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: -0.0001
# Slope: 0.9979
# R² Score: 0.9988
# RMSE: 0.1953

# %% [markdown]
# Scatterplot comparison of EV Peak actual in-vehicle travel time on BRT mode by walk premium

# %%
OpenPath_values = scenarioOne['WALK_PRM_BRTIVTT__EV'].values.reshape(-1, 1)
EMME437_values = scenarioTwo['WALK_PRM_BRTIVTT__EV']

# Fit Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(OpenPath_values, EMME437_values)
y_pred = lin_reg.predict(OpenPath_values)

# Compute R² score and Root Mean Squared Error (RMSE)
r2 = r2_score(EMME437_values, y_pred)
rmse = np.sqrt(mean_squared_error(EMME437_values, y_pred))

# Output regression parameters
intercept = lin_reg.intercept_
slope = lin_reg.coef_[0]

print(f"Intercept: {intercept:.4f}")
print(f"Slope: {slope:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")

plt.figure(figsize=(9, 7))
plt.scatter(OpenPath_values, EMME437_values, color='blue', alpha=0.6, label="Data Points")
plt.plot(OpenPath_values, y_pred, color='red', label=f"Regression Line\n$R^2$={r2:.4f},RMSE={rmse:.4f}")

# Labels and title
plt.xlabel("OpenPath Values")
plt.ylabel("EMME437 Values")
plt.title("Skim Comparison WALK_PRM_BRTIVTT__EV")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Intercept: 0.0012
# Slope: 0.9993
# R² Score: 0.9991
# RMSE: 0.4271

# %% [markdown]
# # Summary of transit EV skim comparison (EMME OpenPath - EMME 4.3.7)

# %% [markdown]
# To display the top 5 rows of skim comparison (sort by WALK_PRM_TOTALIVTT__EV)

# %%
comparison.sort_values(by='WALK_PRM_TOTALIVTT__EV', ascending=False).head()
# Out:
#          Origin  Destination  WALK_PRM_TOTALIVTT__EV  WALK_PRM_LRTIVTT__EV  \
# 6480597    1311           28                   70.68                 64.94
# 6218403    1258           25                   70.68                 64.94
# 6149141    1244           21                   70.68                 64.94
# 6149140    1244           20                   70.68                 64.94
# 6149139    1244           19                   70.68                 64.94
#
#          WALK_PRM_CMRIVTT__EV  WALK_PRM_EXPIVTT__EV  WALK_PRM_LTDEXPIVTT__EV  \
# 6480597                -51.85                  0.00                     0.00
# 6218403                -51.85                  0.00                     0.00
# 6149141                -51.85                  0.00                     0.00
# 6149140                -51.85                  0.00                     0.00
# 6149139                -51.85                  0.00                     0.00
#
#          WALK_PRM_BRTIVTT__EV
# 6480597                 57.59
# 6218403                 57.59
# 6149141                 57.59
# 6149140                 57.59
# 6149139                 57.59

# %% [markdown]
# Below is the summary of select matrices difference in transit EV skim

# %%
comparison.WALK_PRM_TOTALIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.54
# min          -32.92
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           70.68
# Name: WALK_PRM_TOTALIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_LRTIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.48
# min          -53.38
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           64.94
# Name: WALK_PRM_LRTIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_CMRIVTT__EV.describe()
# Out:
# count   24472809.00
# mean          -0.00
# std            0.37
# min          -51.85
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           56.49
# Name: WALK_PRM_CMRIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_EXPIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.00
# std            0.20
# min          -61.09
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           42.53
# Name: WALK_PRM_EXPIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_LTDEXPIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.00
# std            0.00
# min            0.00
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max            0.00
# Name: WALK_PRM_LTDEXPIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_BRTIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.00
# std            0.43
# min          -27.36
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           57.78
# Name: WALK_PRM_BRTIVTT__EV, dtype: float64

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__EV greater than 60

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__EV']>60]
# Out:
#          Origin  Destination  WALK_PRM_TOTALIVTT__EV  WALK_PRM_LRTIVTT__EV  \
# 3359030     680           18                   70.68                 64.94
# 3359031     680           19                   70.68                 64.94
# 3359032     680           20                   70.68                 64.94
# 3359033     680           21                   70.68                 64.94
# 3359035     680           23                   70.68                 64.94
# ...         ...          ...                     ...                   ...
# 7192960    1455           23                   70.68                 64.94
# 7192961    1455           24                   70.68                 64.94
# 7192962    1455           25                   70.68                 64.94
# 7192965    1455           28                   70.68                 64.94
# 7192968    1455           31                   70.68                 64.94
#
#          WALK_PRM_CMRIVTT__EV  WALK_PRM_EXPIVTT__EV  WALK_PRM_LTDEXPIVTT__EV  \
# 3359030                -51.85                  0.00                     0.00
# 3359031                -51.85                  0.00                     0.00
# 3359032                -51.85                  0.00                     0.00
# 3359033                -51.85                  0.00                     0.00
# 3359035                -51.85                  0.00                     0.00
# ...                       ...                   ...                      ...
# 7192960                -51.85                  0.00                     0.00
# 7192961                -51.85                  0.00                     0.00
# 7192962                -51.85                  0.00                     0.00
# 7192965                -51.85                  0.00                     0.00
# 7192968                -51.85                  0.00                     0.00
#
#          WALK_PRM_BRTIVTT__EV
# 3359030                 57.59
# 3359031                 57.59
# 3359032                 57.59
# 3359033                 57.59
# 3359035                 57.59
# ...                       ...
# 7192960                 57.59
# 7192961                 57.59
# 7192962                 57.59
# 7192965                 57.59
# 7192968                 57.59
#
# [942 rows x 8 columns]

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__EV less than -50

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__EV']<-50]
# Out:
#         Origin  Destination  WALK_PRM_TOTALIVTT__EV  WALK_PRM_LRTIVTT__EV  \
# 96250       20         2258                    3.24                -53.38
# 96261       20         2269                    3.24                -53.38
# 195247      40         2315                    0.72                -53.38
#
#         WALK_PRM_CMRIVTT__EV  WALK_PRM_EXPIVTT__EV  WALK_PRM_LTDEXPIVTT__EV  \
# 96250                  56.49                 15.85                     0.00
# 96261                  56.49                 15.85                     0.00
# 195247                 56.49                 15.85                     0.00
#
#         WALK_PRM_BRTIVTT__EV
# 96250                 -15.72
# 96261                 -15.72
# 195247                -18.25
