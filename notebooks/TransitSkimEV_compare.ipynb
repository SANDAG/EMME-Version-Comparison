# %% [markdown]
# ---
# title: "EV"
# format:
#   html:
#     toc: true
#     css: styles.css
#     echo: false
# jupyter: python3
# execute:
#   echo: false # Hides all code globally
# ---

# %%
from util import Skim
from config import scenarioPath_OpenPath
from config import scenarioPath_EMME437
import pandas as pd

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
# Suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# generate comparison
comparison = Skim.comparison(scenarioPath_OpenPath, scenarioPath_EMME437, 'EV', 'transit')

# %% [markdown]
# # Scatterplot Comparison of EV Peak for WALK PRM modes assignment

# %% [markdown]
# Scatterplot comparison of EV Peak total actual in-vehicle travel time by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_TOTALIVTT__EV', scenarioPath_OpenPath, scenarioPath_EMME437, 'EV', 'transit')
# Out:
# Intercept: 0.0041
# Slope: 0.9991
# R² Score: 0.9996
# RMSE: 0.5382

# %% [markdown]
# Scatterplot comparison of EV Peak actual in-vehicle travel time on LRT mode by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_LRTIVTT__EV', scenarioPath_OpenPath, scenarioPath_EMME437, 'EV', 'transit')
# Out:
# Intercept: 0.0037
# Slope: 0.9983
# R² Score: 0.9988
# RMSE: 0.4782

# %% [markdown]
# Scatterplot comparison of EV Peak actual in-vehicle travel time on commuter rail mode by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_CMRIVTT__EV', scenarioPath_OpenPath, scenarioPath_EMME437, 'EV', 'transit')
# Out:
# Intercept: 0.0033
# Slope: 1.0000
# R² Score: 0.9971
# RMSE: 0.3731

# %% [markdown]
# Scatterplot comparison of EV Peak actual in-vehicle travel time on express bus mode by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_EXPIVTT__EV', scenarioPath_OpenPath, scenarioPath_EMME437, 'EV', 'transit')
# Out:
# Intercept: -0.0001
# Slope: 0.9979
# R² Score: 0.9988
# RMSE: 0.1953

# %% [markdown]
# Scatterplot comparison of EV Peak actual in-vehicle travel time on BRT mode by walk premium

# %%
Skim.regression_scatter_plot('WALK_PRM_BRTIVTT__EV', scenarioPath_OpenPath, scenarioPath_EMME437, 'EV', 'transit')
# Out:
# Intercept: 0.0012
# Slope: 0.9993
# R² Score: 0.9991
# RMSE: 0.4271

# %% [markdown]
# # Summary of transit EV skim comparison (EMME OpenPath - EMME 4.3.7)

# %% [markdown]
# To display the top 5 rows of skim comparison (sort by WALK_PRM_TOTALIVTT__EV)

# %%
comparison.sort_values(by='WALK_PRM_TOTALIVTT__EV', ascending=False).head().style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'blue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_4467e thead th {
#   background-color: blue;
# }
# </style>
# <table id="T_4467e">
#   <thead>
#     <tr>
#       <th id="T_4467e_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_4467e_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_4467e_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__EV</th>
#       <th id="T_4467e_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__EV</th>
#       <th id="T_4467e_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__EV</th>
#       <th id="T_4467e_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__EV</th>
#       <th id="T_4467e_level0_col6" class="col_heading level0 col6" >WALK_PRM_LTDEXPIVTT__EV</th>
#       <th id="T_4467e_level0_col7" class="col_heading level0 col7" >WALK_PRM_BRTIVTT__EV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4467e_row0_col0" class="data row0 col0" >1311</td>
#       <td id="T_4467e_row0_col1" class="data row0 col1" >28</td>
#       <td id="T_4467e_row0_col2" class="data row0 col2" >70.677795</td>
#       <td id="T_4467e_row0_col3" class="data row0 col3" >64.941448</td>
#       <td id="T_4467e_row0_col4" class="data row0 col4" >-51.852757</td>
#       <td id="T_4467e_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_4467e_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_4467e_row0_col7" class="data row0 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_4467e_row1_col0" class="data row1 col0" >1258</td>
#       <td id="T_4467e_row1_col1" class="data row1 col1" >25</td>
#       <td id="T_4467e_row1_col2" class="data row1 col2" >70.677795</td>
#       <td id="T_4467e_row1_col3" class="data row1 col3" >64.941448</td>
#       <td id="T_4467e_row1_col4" class="data row1 col4" >-51.852757</td>
#       <td id="T_4467e_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_4467e_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_4467e_row1_col7" class="data row1 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_4467e_row2_col0" class="data row2 col0" >1244</td>
#       <td id="T_4467e_row2_col1" class="data row2 col1" >21</td>
#       <td id="T_4467e_row2_col2" class="data row2 col2" >70.677795</td>
#       <td id="T_4467e_row2_col3" class="data row2 col3" >64.941448</td>
#       <td id="T_4467e_row2_col4" class="data row2 col4" >-51.852757</td>
#       <td id="T_4467e_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_4467e_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_4467e_row2_col7" class="data row2 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_4467e_row3_col0" class="data row3 col0" >1244</td>
#       <td id="T_4467e_row3_col1" class="data row3 col1" >20</td>
#       <td id="T_4467e_row3_col2" class="data row3 col2" >70.677795</td>
#       <td id="T_4467e_row3_col3" class="data row3 col3" >64.941448</td>
#       <td id="T_4467e_row3_col4" class="data row3 col4" >-51.852757</td>
#       <td id="T_4467e_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_4467e_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_4467e_row3_col7" class="data row3 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_4467e_row4_col0" class="data row4 col0" >1244</td>
#       <td id="T_4467e_row4_col1" class="data row4 col1" >19</td>
#       <td id="T_4467e_row4_col2" class="data row4 col2" >70.677795</td>
#       <td id="T_4467e_row4_col3" class="data row4 col3" >64.941448</td>
#       <td id="T_4467e_row4_col4" class="data row4 col4" >-51.852757</td>
#       <td id="T_4467e_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_4467e_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_4467e_row4_col7" class="data row4 col7" >57.589096</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Below is the summary of select matrices difference in transit EV skim

# %%
comparison.WALK_PRM_TOTALIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.54
# min          -32.92
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           70.68
# Name: WALK_PRM_TOTALIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_LRTIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.01
# std            0.48
# min          -53.38
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           64.94
# Name: WALK_PRM_LRTIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_CMRIVTT__EV.describe()
# Out:
# count   24472809.00
# mean          -0.00
# std            0.37
# min          -51.85
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           56.49
# Name: WALK_PRM_CMRIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_EXPIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.00
# std            0.20
# min          -61.09
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           42.53
# Name: WALK_PRM_EXPIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_LTDEXPIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.00
# std            0.00
# min            0.00
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max            0.00
# Name: WALK_PRM_LTDEXPIVTT__EV, dtype: float64

# %%
comparison.WALK_PRM_BRTIVTT__EV.describe()
# Out:
# count   24472809.00
# mean           0.00
# std            0.43
# min          -27.36
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max           57.78
# Name: WALK_PRM_BRTIVTT__EV, dtype: float64

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__EV greater than 60

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__EV']>60].style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'blue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_53be3 thead th {
#   background-color: blue;
# }
# </style>
# <table id="T_53be3">
#   <thead>
#     <tr>
#       <th id="T_53be3_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_53be3_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_53be3_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__EV</th>
#       <th id="T_53be3_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__EV</th>
#       <th id="T_53be3_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__EV</th>
#       <th id="T_53be3_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__EV</th>
#       <th id="T_53be3_level0_col6" class="col_heading level0 col6" >WALK_PRM_LTDEXPIVTT__EV</th>
#       <th id="T_53be3_level0_col7" class="col_heading level0 col7" >WALK_PRM_BRTIVTT__EV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_53be3_row0_col0" class="data row0 col0" >680</td>
#       <td id="T_53be3_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_53be3_row0_col2" class="data row0 col2" >70.677780</td>
#       <td id="T_53be3_row0_col3" class="data row0 col3" >64.941450</td>
#       <td id="T_53be3_row0_col4" class="data row0 col4" >-51.852757</td>
#       <td id="T_53be3_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_53be3_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_53be3_row0_col7" class="data row0 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row1_col0" class="data row1 col0" >680</td>
#       <td id="T_53be3_row1_col1" class="data row1 col1" >19</td>
#       <td id="T_53be3_row1_col2" class="data row1 col2" >70.677780</td>
#       <td id="T_53be3_row1_col3" class="data row1 col3" >64.941450</td>
#       <td id="T_53be3_row1_col4" class="data row1 col4" >-51.852757</td>
#       <td id="T_53be3_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_53be3_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_53be3_row1_col7" class="data row1 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row2_col0" class="data row2 col0" >680</td>
#       <td id="T_53be3_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_53be3_row2_col2" class="data row2 col2" >70.677780</td>
#       <td id="T_53be3_row2_col3" class="data row2 col3" >64.941450</td>
#       <td id="T_53be3_row2_col4" class="data row2 col4" >-51.852757</td>
#       <td id="T_53be3_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_53be3_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_53be3_row2_col7" class="data row2 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row3_col0" class="data row3 col0" >680</td>
#       <td id="T_53be3_row3_col1" class="data row3 col1" >21</td>
#       <td id="T_53be3_row3_col2" class="data row3 col2" >70.677780</td>
#       <td id="T_53be3_row3_col3" class="data row3 col3" >64.941450</td>
#       <td id="T_53be3_row3_col4" class="data row3 col4" >-51.852757</td>
#       <td id="T_53be3_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_53be3_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_53be3_row3_col7" class="data row3 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row4_col0" class="data row4 col0" >680</td>
#       <td id="T_53be3_row4_col1" class="data row4 col1" >23</td>
#       <td id="T_53be3_row4_col2" class="data row4 col2" >70.677780</td>
#       <td id="T_53be3_row4_col3" class="data row4 col3" >64.941450</td>
#       <td id="T_53be3_row4_col4" class="data row4 col4" >-51.852757</td>
#       <td id="T_53be3_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_53be3_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_53be3_row4_col7" class="data row4 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row5_col0" class="data row5 col0" >680</td>
#       <td id="T_53be3_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_53be3_row5_col2" class="data row5 col2" >70.677780</td>
#       <td id="T_53be3_row5_col3" class="data row5 col3" >64.941450</td>
#       <td id="T_53be3_row5_col4" class="data row5 col4" >-51.852757</td>
#       <td id="T_53be3_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_53be3_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_53be3_row5_col7" class="data row5 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row6_col0" class="data row6 col0" >680</td>
#       <td id="T_53be3_row6_col1" class="data row6 col1" >25</td>
#       <td id="T_53be3_row6_col2" class="data row6 col2" >70.677780</td>
#       <td id="T_53be3_row6_col3" class="data row6 col3" >64.941450</td>
#       <td id="T_53be3_row6_col4" class="data row6 col4" >-51.852757</td>
#       <td id="T_53be3_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_53be3_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_53be3_row6_col7" class="data row6 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row7_col0" class="data row7 col0" >680</td>
#       <td id="T_53be3_row7_col1" class="data row7 col1" >28</td>
#       <td id="T_53be3_row7_col2" class="data row7 col2" >70.677780</td>
#       <td id="T_53be3_row7_col3" class="data row7 col3" >64.941450</td>
#       <td id="T_53be3_row7_col4" class="data row7 col4" >-51.852757</td>
#       <td id="T_53be3_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_53be3_row7_col6" class="data row7 col6" >0.000000</td>
#       <td id="T_53be3_row7_col7" class="data row7 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row8_col0" class="data row8 col0" >680</td>
#       <td id="T_53be3_row8_col1" class="data row8 col1" >31</td>
#       <td id="T_53be3_row8_col2" class="data row8 col2" >70.677780</td>
#       <td id="T_53be3_row8_col3" class="data row8 col3" >64.941450</td>
#       <td id="T_53be3_row8_col4" class="data row8 col4" >-51.852757</td>
#       <td id="T_53be3_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_53be3_row8_col6" class="data row8 col6" >0.000000</td>
#       <td id="T_53be3_row8_col7" class="data row8 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row9_col0" class="data row9 col0" >699</td>
#       <td id="T_53be3_row9_col1" class="data row9 col1" >18</td>
#       <td id="T_53be3_row9_col2" class="data row9 col2" >70.677780</td>
#       <td id="T_53be3_row9_col3" class="data row9 col3" >64.941450</td>
#       <td id="T_53be3_row9_col4" class="data row9 col4" >-51.852757</td>
#       <td id="T_53be3_row9_col5" class="data row9 col5" >0.000000</td>
#       <td id="T_53be3_row9_col6" class="data row9 col6" >0.000000</td>
#       <td id="T_53be3_row9_col7" class="data row9 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row10_col0" class="data row10 col0" >699</td>
#       <td id="T_53be3_row10_col1" class="data row10 col1" >19</td>
#       <td id="T_53be3_row10_col2" class="data row10 col2" >70.677780</td>
#       <td id="T_53be3_row10_col3" class="data row10 col3" >64.941450</td>
#       <td id="T_53be3_row10_col4" class="data row10 col4" >-51.852757</td>
#       <td id="T_53be3_row10_col5" class="data row10 col5" >0.000000</td>
#       <td id="T_53be3_row10_col6" class="data row10 col6" >0.000000</td>
#       <td id="T_53be3_row10_col7" class="data row10 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row11_col0" class="data row11 col0" >699</td>
#       <td id="T_53be3_row11_col1" class="data row11 col1" >20</td>
#       <td id="T_53be3_row11_col2" class="data row11 col2" >70.677780</td>
#       <td id="T_53be3_row11_col3" class="data row11 col3" >64.941450</td>
#       <td id="T_53be3_row11_col4" class="data row11 col4" >-51.852757</td>
#       <td id="T_53be3_row11_col5" class="data row11 col5" >0.000000</td>
#       <td id="T_53be3_row11_col6" class="data row11 col6" >0.000000</td>
#       <td id="T_53be3_row11_col7" class="data row11 col7" >57.589096</td>
#     </tr>
#     <tr>
#       <td id="T_53be3_row12_col0" class="data row12 col0" >699</td>
#       <td id="T_53be3_row12_col1"

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__EV less than -50

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__EV']<-50].style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'blue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_add06 thead th {
#   background-color: blue;
# }
# </style>
# <table id="T_add06">
#   <thead>
#     <tr>
#       <th id="T_add06_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_add06_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_add06_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__EV</th>
#       <th id="T_add06_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__EV</th>
#       <th id="T_add06_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__EV</th>
#       <th id="T_add06_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__EV</th>
#       <th id="T_add06_level0_col6" class="col_heading level0 col6" >WALK_PRM_LTDEXPIVTT__EV</th>
#       <th id="T_add06_level0_col7" class="col_heading level0 col7" >WALK_PRM_BRTIVTT__EV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_add06_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_add06_row0_col1" class="data row0 col1" >2258</td>
#       <td id="T_add06_row0_col2" class="data row0 col2" >3.239212</td>
#       <td id="T_add06_row0_col3" class="data row0 col3" >-53.380180</td>
#       <td id="T_add06_row0_col4" class="data row0 col4" >56.493736</td>
#       <td id="T_add06_row0_col5" class="data row0 col5" >15.848077</td>
#       <td id="T_add06_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_add06_row0_col7" class="data row0 col7" >-15.722418</td>
#     </tr>
#     <tr>
#       <td id="T_add06_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_add06_row1_col1" class="data row1 col1" >2269</td>
#       <td id="T_add06_row1_col2" class="data row1 col2" >3.239212</td>
#       <td id="T_add06_row1_col3" class="data row1 col3" >-53.380180</td>
#       <td id="T_add06_row1_col4" class="data row1 col4" >56.493736</td>
#       <td id="T_add06_row1_col5" class="data row1 col5" >15.848077</td>
#       <td id="T_add06_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_add06_row1_col7" class="data row1 col7" >-15.722420</td>
#     </tr>
#     <tr>
#       <td id="T_add06_row2_col0" class="data row2 col0" >40</td>
#       <td id="T_add06_row2_col1" class="data row2 col1" >2315</td>
#       <td id="T_add06_row2_col2" class="data row2 col2" >0.716064</td>
#       <td id="T_add06_row2_col3" class="data row2 col3" >-53.380180</td>
#       <td id="T_add06_row2_col4" class="data row2 col4" >56.493736</td>
#       <td id="T_add06_row2_col5" class="data row2 col5" >15.848077</td>
#       <td id="T_add06_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_add06_row2_col7" class="data row2 col7" >-18.245571</td>
#     </tr>
#   </tbody>
# </table>
