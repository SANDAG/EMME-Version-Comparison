# %% [markdown]
# ---
# title: "EMME 4.3.7"
# format:
#   html:
#     toc: true
#     css: styles.css
#     echo: false
# jupyter: python3
# execute:
#   echo: false # Hides all code globally
# ---

# %%
from util import Skim
from util import SkimCompare

# %%
# Suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
base_skim = Skim() #no label initially
#read 5 matrices from transit AM skims
base_skim.skimReader(
    scenario_path=r'T:\STORAGE-63T\2025RP_draft\abm_runs_v2\2022_S0_v2',
    skim='transit',
    time_periods='AM',
    desc_label='EMME 4.3.7 Original Demand'
)

# %%
comp_skim = Skim()
comp_skim.skimReader(
    scenario_path=r'T:\STORAGE-63T\ABM3_EMME_upgrade\2022_S0_v2_obs',
    skim='transit',
    time_periods='AM',
    desc_label='EMME 4.3.7 Observed Demand (OBS)'
)

# %%
print('Scenarios to be compared: ' + base_skim.desc_label + ' VS ' + comp_skim.desc_label)
# Out:
# Scenarios to be compared: EMME 4.3.7 Original Demand VS EMME 4.3.7 Observed Demand (OBS)

# %% [markdown]
# # Scatterplot Comparison of AM Peak for WALK PRM modes assignment

# %% [markdown]
# Scatterplot comparison of AM Peak total actual in-vehicle travel time by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_TOTALIVTT__AM')
# Out:
# Intercept: 0.0000
# Slope: 1.0000
# R² Score: 1.0000
# RMSE: 0.0353

# %% [markdown]
# Scatterplot comparison of AM Peak actual in-vehicle travel time on LRT mode by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_LRTIVTT__AM')
# Out:
# Intercept: 0.0000
# Slope: 1.0000
# R² Score: 1.0000
# RMSE: 0.0233

# %% [markdown]
# Scatterplot comparison of AM Peak actual in-vehicle travel time on commuter rail mode by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_CMRIVTT__AM')
# Out:
# Intercept: 0.0001
# Slope: 1.0000
# R² Score: 0.9999
# RMSE: 0.0667

# %% [markdown]
# Scatterplot comparison of AM Peak actual in-vehicle travel time on express bus mode by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_EXPIVTT__AM')
# Out:
# Intercept: 0.0000
# Slope: 1.0000
# R² Score: 1.0000
# RMSE: 0.0082

# %% [markdown]
# Scatterplot comparison of AM Peak actual in-vehicle travel time on BRT mode by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_BRTIVTT__AM')
# Out:
# Intercept: 0.0000
# Slope: 1.0000
# R² Score: 1.0000
# RMSE: 0.0786

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_LOC_TOTALIVTT__AM')
# Out:
# Intercept: -0.0000
# Slope: 1.0000
# R² Score: 1.0000
# RMSE: 0.0000

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_MIX_TOTALIVTT__AM')
# Out:
# Intercept: -0.0000
# Slope: 1.0000
# R² Score: 1.0000
# RMSE: 0.0000

# %% [markdown]
# # Summary of transit AM skim comparison (EMME 4.3.7 Observed Demand - EMME 4.3.7 Original Demand)

# %% [markdown]
# To display the top 5 rows of skim comparison (sort by WALK_PRM_TOTALIVTT__AM)

# %%
# generate comparison
comparison = SkimCompare.comparison(base_skim.skim_df, comp_skim.skim_df)

# %%
comparison.sort_values(by='WALK_PRM_TOTALIVTT__AM', ascending=False).head().round(2).applymap(lambda x: f"{x:.2f}".rstrip('0').rstrip('.')).style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'lightblue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_0e4d0 thead th {
#   background-color: lightblue;
# }
# </style>
# <table id="T_0e4d0">
#   <thead>
#     <tr>
#       <th id="T_0e4d0_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_0e4d0_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_0e4d0_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__AM</th>
#       <th id="T_0e4d0_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__AM</th>
#       <th id="T_0e4d0_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__AM</th>
#       <th id="T_0e4d0_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__AM</th>
#       <th id="T_0e4d0_level0_col6" class="col_heading level0 col6" >WALK_PRM_BRTIVTT__AM</th>
#       <th id="T_0e4d0_level0_col7" class="col_heading level0 col7" >WALK_LOC_TOTALIVTT__AM</th>
#       <th id="T_0e4d0_level0_col8" class="col_heading level0 col8" >WALK_MIX_TOTALIVTT__AM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0e4d0_row0_col0" class="data row0 col0" >1626</td>
#       <td id="T_0e4d0_row0_col1" class="data row0 col1" >504</td>
#       <td id="T_0e4d0_row0_col2" class="data row0 col2" >32.02</td>
#       <td id="T_0e4d0_row0_col3" class="data row0 col3" >20.81</td>
#       <td id="T_0e4d0_row0_col4" class="data row0 col4" >-58.57</td>
#       <td id="T_0e4d0_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_0e4d0_row0_col6" class="data row0 col6" >69.78</td>
#       <td id="T_0e4d0_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_0e4d0_row0_col8" class="data row0 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_0e4d0_row1_col0" class="data row1 col0" >1626</td>
#       <td id="T_0e4d0_row1_col1" class="data row1 col1" >568</td>
#       <td id="T_0e4d0_row1_col2" class="data row1 col2" >32.02</td>
#       <td id="T_0e4d0_row1_col3" class="data row1 col3" >20.81</td>
#       <td id="T_0e4d0_row1_col4" class="data row1 col4" >-58.57</td>
#       <td id="T_0e4d0_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_0e4d0_row1_col6" class="data row1 col6" >69.78</td>
#       <td id="T_0e4d0_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_0e4d0_row1_col8" class="data row1 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_0e4d0_row2_col0" class="data row2 col0" >1626</td>
#       <td id="T_0e4d0_row2_col1" class="data row2 col1" >723</td>
#       <td id="T_0e4d0_row2_col2" class="data row2 col2" >32.02</td>
#       <td id="T_0e4d0_row2_col3" class="data row2 col3" >20.81</td>
#       <td id="T_0e4d0_row2_col4" class="data row2 col4" >-58.57</td>
#       <td id="T_0e4d0_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_0e4d0_row2_col6" class="data row2 col6" >69.78</td>
#       <td id="T_0e4d0_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_0e4d0_row2_col8" class="data row2 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_0e4d0_row3_col0" class="data row3 col0" >1626</td>
#       <td id="T_0e4d0_row3_col1" class="data row3 col1" >498</td>
#       <td id="T_0e4d0_row3_col2" class="data row3 col2" >32.02</td>
#       <td id="T_0e4d0_row3_col3" class="data row3 col3" >20.81</td>
#       <td id="T_0e4d0_row3_col4" class="data row3 col4" >-58.57</td>
#       <td id="T_0e4d0_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_0e4d0_row3_col6" class="data row3 col6" >69.78</td>
#       <td id="T_0e4d0_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_0e4d0_row3_col8" class="data row3 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_0e4d0_row4_col0" class="data row4 col0" >1665</td>
#       <td id="T_0e4d0_row4_col1" class="data row4 col1" >419</td>
#       <td id="T_0e4d0_row4_col2" class="data row4 col2" >19.46</td>
#       <td id="T_0e4d0_row4_col3" class="data row4 col3" >10.88</td>
#       <td id="T_0e4d0_row4_col4" class="data row4 col4" >-26.31</td>
#       <td id="T_0e4d0_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_0e4d0_row4_col6" class="data row4 col6" >34.89</td>
#       <td id="T_0e4d0_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_0e4d0_row4_col8" class="data row4 col8" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Below is the summary of selected matrices difference in transit AM skim

# %%
comparison_excluded = comparison.drop(columns=['Origin', 'Destination'])
desc = comparison_excluded.describe().applymap(lambda x: f"{x:,.2f}").style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'lightblue')]}]  # Custom header style
)
desc
# Out:
# <style type="text/css">
# #T_c843e thead th {
#   background-color: lightblue;
# }
# </style>
# <table id="T_c843e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c843e_level0_col0" class="col_heading level0 col0" >WALK_PRM_TOTALIVTT__AM</th>
#       <th id="T_c843e_level0_col1" class="col_heading level0 col1" >WALK_PRM_LRTIVTT__AM</th>
#       <th id="T_c843e_level0_col2" class="col_heading level0 col2" >WALK_PRM_CMRIVTT__AM</th>
#       <th id="T_c843e_level0_col3" class="col_heading level0 col3" >WALK_PRM_EXPIVTT__AM</th>
#       <th id="T_c843e_level0_col4" class="col_heading level0 col4" >WALK_PRM_BRTIVTT__AM</th>
#       <th id="T_c843e_level0_col5" class="col_heading level0 col5" >WALK_LOC_TOTALIVTT__AM</th>
#       <th id="T_c843e_level0_col6" class="col_heading level0 col6" >WALK_MIX_TOTALIVTT__AM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c843e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_c843e_row0_col0" class="data row0 col0" >24,472,809.00</td>
#       <td id="T_c843e_row0_col1" class="data row0 col1" >24,472,809.00</td>
#       <td id="T_c843e_row0_col2" class="data row0 col2" >24,472,809.00</td>
#       <td id="T_c843e_row0_col3" class="data row0 col3" >24,472,809.00</td>
#       <td id="T_c843e_row0_col4" class="data row0 col4" >24,472,809.00</td>
#       <td id="T_c843e_row0_col5" class="data row0 col5" >24,472,809.00</td>
#       <td id="T_c843e_row0_col6" class="data row0 col6" >24,472,809.00</td>
#     </tr>
#     <tr>
#       <th id="T_c843e_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_c843e_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_c843e_row1_col1" class="data row1 col1" >-0.00</td>
#       <td id="T_c843e_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_c843e_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_c843e_row1_col4" class="data row1 col4" >-0.00</td>
#       <td id="T_c843e_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_c843e_row1_col6" class="data row1 col6" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c843e_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_c843e_row2_col0" class="data row2 col0" >0.04</td>
#       <td id="T_c843e_row2_col1" class="data row2 col1" >0.02</td>
#       <td id="T_c843e_row2_col2" class="data row2 col2" >0.07</td>
#       <td id="T_c843e_row2_col3" class="data row2 col3" >0.01</td>
#       <td id="T_c843e_row2_col4" class="data row2 col4" >0.08</td>
#       <td id="T_c843e_row2_col5" class="data row2 col5" >0.00</td>
#       <td id="T_c843e_row2_col6" class="data row2 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c843e_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_c843e_row3_col0" class="data row3 col0" >-32.02</td>
#       <td id="T_c843e_row3_col1" class="data row3 col1" >-20.81</td>
#       <td id="T_c843e_row3_col2" class="data row3 col2" >-58.57</td>
#       <td id="T_c843e_row3_col3" class="data row3 col3" >-0.00</td>
#       <td id="T_c843e_row3_col4" class="data row3 col4" >-69.78</td>
#       <td id="T_c843e_row3_col5" class="data row3 col5" >-0.00</td>
#       <td id="T_c843e_row3_col6" class="data row3 col6" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c843e_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_c843e_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_c843e_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_c843e_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_c843e_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_c843e_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_c843e_row4_col5" class="data row4 col5" >0.00</td>
#       <td id="T_c843e_row4_col6" class="data row4 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c843e_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_c843e_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_c843e_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_c843e_row5_col2" class="data row5 col2" >0.00</td>
#       <td id="T_c843e_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_c843e_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_c843e_row5_col5" class="data row5 col5" >0.00</td>
#       <td id="T_c843e_row5_col6" class="data row5 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c843e_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_c843e_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_c843e_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_c843e_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_c843e_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_c843e_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_c843e_row6_col5" class="data row6 col5" >0.00</td>
#       <td id="T_c843e_row6_col6" class="data row6 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c843e_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_c843e_row7_col0" class="data row7 col0" >32.02</td>
#       <td id="T_c843e_row7_col1" class="data row7 col1" >20.81</td>
#       <td id="T_c843e_row7_col2" class="data row7 col2" >58.57</td>
#       <td id="T_c843e_row7_col3" class="data row7 col3" >5.39</td>
#       <td id="T_c843e_row7_col4" class="data row7 col4" >69.78</td>
#       <td id="T_c843e_row7_col5" class="data row7 col5" >0.00</td>
#       <td id="T_c843e_row7_col6" class="data row7 col6" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__AM greater than 50

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__AM']>40].round(2).applymap(lambda x: f"{x:.2f}".rstrip('0').rstrip('.')).style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'lightblue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_ade2f thead th {
#   background-color: lightblue;
# }
# </style>
# <table id="T_ade2f">
#   <thead>
#     <tr>
#       <th id="T_ade2f_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_ade2f_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_ade2f_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__AM</th>
#       <th id="T_ade2f_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__AM</th>
#       <th id="T_ade2f_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__AM</th>
#       <th id="T_ade2f_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__AM</th>
#       <th id="T_ade2f_level0_col6" class="col_heading level0 col6" >WALK_PRM_BRTIVTT__AM</th>
#       <th id="T_ade2f_level0_col7" class="col_heading level0 col7" >WALK_LOC_TOTALIVTT__AM</th>
#       <th id="T_ade2f_level0_col8" class="col_heading level0 col8" >WALK_MIX_TOTALIVTT__AM</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__AM less than -50

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__AM']<-20].round(2).applymap(lambda x: f"{x:.2f}".rstrip('0').rstrip('.')).style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'lightblue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_00b55 thead th {
#   background-color: lightblue;
# }
# </style>
# <table id="T_00b55">
#   <thead>
#     <tr>
#       <th id="T_00b55_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_00b55_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_00b55_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__AM</th>
#       <th id="T_00b55_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__AM</th>
#       <th id="T_00b55_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__AM</th>
#       <th id="T_00b55_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__AM</th>
#       <th id="T_00b55_level0_col6" class="col_heading level0 col6" >WALK_PRM_BRTIVTT__AM</th>
#       <th id="T_00b55_level0_col7" class="col_heading level0 col7" >WALK_LOC_TOTALIVTT__AM</th>
#       <th id="T_00b55_level0_col8" class="col_heading level0 col8" >WALK_MIX_TOTALIVTT__AM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_00b55_row0_col0" class="data row0 col0" >1626</td>
#       <td id="T_00b55_row0_col1" class="data row0 col1" >462</td>
#       <td id="T_00b55_row0_col2" class="data row0 col2" >-32.02</td>
#       <td id="T_00b55_row0_col3" class="data row0 col3" >-20.81</td>
#       <td id="T_00b55_row0_col4" class="data row0 col4" >58.57</td>
#       <td id="T_00b55_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_00b55_row0_col6" class="data row0 col6" >-69.78</td>
#       <td id="T_00b55_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_00b55_row0_col8" class="data row0 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_00b55_row1_col0" class="data row1 col0" >1626</td>
#       <td id="T_00b55_row1_col1" class="data row1 col1" >496</td>
#       <td id="T_00b55_row1_col2" class="data row1 col2" >-32.02</td>
#       <td id="T_00b55_row1_col3" class="data row1 col3" >-20.81</td>
#       <td id="T_00b55_row1_col4" class="data row1 col4" >58.57</td>
#       <td id="T_00b55_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_00b55_row1_col6" class="data row1 col6" >-69.78</td>
#       <td id="T_00b55_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_00b55_row1_col8" class="data row1 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_00b55_row2_col0" class="data row2 col0" >1626</td>
#       <td id="T_00b55_row2_col1" class="data row2 col1" >575</td>
#       <td id="T_00b55_row2_col2" class="data row2 col2" >-32.02</td>
#       <td id="T_00b55_row2_col3" class="data row2 col3" >-20.81</td>
#       <td id="T_00b55_row2_col4" class="data row2 col4" >58.57</td>
#       <td id="T_00b55_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_00b55_row2_col6" class="data row2 col6" >-69.78</td>
#       <td id="T_00b55_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_00b55_row2_col8" class="data row2 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_00b55_row3_col0" class="data row3 col0" >1626</td>
#       <td id="T_00b55_row3_col1" class="data row3 col1" >581</td>
#       <td id="T_00b55_row3_col2" class="data row3 col2" >-32.02</td>
#       <td id="T_00b55_row3_col3" class="data row3 col3" >-20.81</td>
#       <td id="T_00b55_row3_col4" class="data row3 col4" >58.57</td>
#       <td id="T_00b55_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_00b55_row3_col6" class="data row3 col6" >-69.78</td>
#       <td id="T_00b55_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_00b55_row3_col8" class="data row3 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_00b55_row4_col0" class="data row4 col0" >1626</td>
#       <td id="T_00b55_row4_col1" class="data row4 col1" >821</td>
#       <td id="T_00b55_row4_col2" class="data row4 col2" >-32.02</td>
#       <td id="T_00b55_row4_col3" class="data row4 col3" >-20.81</td>
#       <td id="T_00b55_row4_col4" class="data row4 col4" >58.57</td>
#       <td id="T_00b55_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_00b55_row4_col6" class="data row4 col6" >-69.78</td>
#       <td id="T_00b55_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_00b55_row4_col8" class="data row4 col8" >0</td>
#     </tr>
#   </tbody>
# </table>
