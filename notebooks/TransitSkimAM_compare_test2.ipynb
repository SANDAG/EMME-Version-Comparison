# %% [markdown]
# ---
# title: "Test 2"
# format:
#   html:
#     toc: true
#     css: styles.css
#     echo: false
# jupyter: python3
# execute:
#   echo: false # Hides all code globally
# ---

# %%
from util import Skim
from util import SkimCompare

# %%
# Suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
base_skim = Skim() #no label initially
#read 5 matrices from transit AM skims
base_skim.skimReader(
    scenario_path=r'T:\STORAGE-63T\ABM3_EMME_upgrade\2022_EMME437',
    skim='transit',
    time_periods='AM',
    desc_label='EMME 4.3.7 Initialization'
)

# %%
comp_skim = Skim()
comp_skim.skimReader(
    scenario_path=r'T:\STORAGE-63T\ABM3_EMME_upgrade\2022_OpenPath',
    skim='transit',
    time_periods='AM',
    desc_label='EMME OpenPath Initialization'
)

# %%
print('Scenarios to be compared: ' + base_skim.desc_label + ' VS ' + comp_skim.desc_label)
# Out:
# Scenarios to be compared: EMME 4.3.7 Initialization VS EMME OpenPath Initialization

# %% [markdown]
# # Scatterplot Comparison of AM Peak for WALK PRM modes assignment

# %% [markdown]
# Scatterplot comparison of AM Peak total actual in-vehicle travel time by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_TOTALIVTT__AM')
# Out:
# Intercept: 0.0036
# Slope: 1.0008
# R² Score: 0.9997
# RMSE: 0.4779

# %% [markdown]
# Scatterplot comparison of AM Peak actual in-vehicle travel time on LRT mode by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_LRTIVTT__AM')
# Out:
# Intercept: 0.0083
# Slope: 0.9991
# R² Score: 0.9985
# RMSE: 0.4922

# %% [markdown]
# Scatterplot comparison of AM Peak actual in-vehicle travel time on commuter rail mode by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_CMRIVTT__AM')
# Out:
# Intercept: 0.0053
# Slope: 1.0011
# R² Score: 0.9948
# RMSE: 0.5589

# %% [markdown]
# Scatterplot comparison of AM Peak actual in-vehicle travel time on express bus mode by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_EXPIVTT__AM')
# Out:
# Intercept: 0.0019
# Slope: 0.9982
# R² Score: 0.9982
# RMSE: 0.2853

# %% [markdown]
# Scatterplot comparison of AM Peak actual in-vehicle travel time on BRT mode by walk premium

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_PRM_BRTIVTT__AM')
# Out:
# Intercept: 0.0057
# Slope: 0.9996
# R² Score: 0.9979
# RMSE: 0.6946

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_LOC_TOTALIVTT__AM')
# Out:
# Intercept: -0.0050
# Slope: 1.0010
# R² Score: 1.0000
# RMSE: 0.3886

# %%
SkimCompare.regression_scatter_plot(base_skim, comp_skim,'WALK_MIX_TOTALIVTT__AM')
# Out:
# Intercept: 0.1064
# Slope: 0.9988
# R² Score: 0.9977
# RMSE: 2.3245

# %% [markdown]
# # Summary of transit AM skim comparison (EMME OpenPath - EMME 4.3.7)

# %% [markdown]
# To display the top 5 rows of skim comparison (sort by WALK_PRM_TOTALIVTT__AM)

# %%
# generate comparison
comparison = SkimCompare.comparison(base_skim.skim_df, comp_skim.skim_df)

# %%
comparison.sort_values(by='WALK_PRM_TOTALIVTT__AM', ascending=False).head().round(2).applymap(lambda x: f"{x:.2f}".rstrip('0').rstrip('.')).style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'lightblue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_67114 thead th {
#   background-color: lightblue;
# }
# </style>
# <table id="T_67114">
#   <thead>
#     <tr>
#       <th id="T_67114_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_67114_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_67114_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__AM</th>
#       <th id="T_67114_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__AM</th>
#       <th id="T_67114_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__AM</th>
#       <th id="T_67114_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__AM</th>
#       <th id="T_67114_level0_col6" class="col_heading level0 col6" >WALK_PRM_BRTIVTT__AM</th>
#       <th id="T_67114_level0_col7" class="col_heading level0 col7" >WALK_LOC_TOTALIVTT__AM</th>
#       <th id="T_67114_level0_col8" class="col_heading level0 col8" >WALK_MIX_TOTALIVTT__AM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_67114_row0_col0" class="data row0 col0" >1896</td>
#       <td id="T_67114_row0_col1" class="data row0 col1" >150</td>
#       <td id="T_67114_row0_col2" class="data row0 col2" >43.18</td>
#       <td id="T_67114_row0_col3" class="data row0 col3" >33.76</td>
#       <td id="T_67114_row0_col4" class="data row0 col4" >-58.57</td>
#       <td id="T_67114_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_67114_row0_col6" class="data row0 col6" >68</td>
#       <td id="T_67114_row0_col7" class="data row0 col7" >0.33</td>
#       <td id="T_67114_row0_col8" class="data row0 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_67114_row1_col0" class="data row1 col0" >1895</td>
#       <td id="T_67114_row1_col1" class="data row1 col1" >138</td>
#       <td id="T_67114_row1_col2" class="data row1 col2" >43.18</td>
#       <td id="T_67114_row1_col3" class="data row1 col3" >33.76</td>
#       <td id="T_67114_row1_col4" class="data row1 col4" >-58.57</td>
#       <td id="T_67114_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_67114_row1_col6" class="data row1 col6" >68</td>
#       <td id="T_67114_row1_col7" class="data row1 col7" >0.33</td>
#       <td id="T_67114_row1_col8" class="data row1 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_67114_row2_col0" class="data row2 col0" >1895</td>
#       <td id="T_67114_row2_col1" class="data row2 col1" >160</td>
#       <td id="T_67114_row2_col2" class="data row2 col2" >43.18</td>
#       <td id="T_67114_row2_col3" class="data row2 col3" >33.76</td>
#       <td id="T_67114_row2_col4" class="data row2 col4" >-58.57</td>
#       <td id="T_67114_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_67114_row2_col6" class="data row2 col6" >68</td>
#       <td id="T_67114_row2_col7" class="data row2 col7" >0.34</td>
#       <td id="T_67114_row2_col8" class="data row2 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_67114_row3_col0" class="data row3 col0" >1895</td>
#       <td id="T_67114_row3_col1" class="data row3 col1" >154</td>
#       <td id="T_67114_row3_col2" class="data row3 col2" >43.18</td>
#       <td id="T_67114_row3_col3" class="data row3 col3" >33.76</td>
#       <td id="T_67114_row3_col4" class="data row3 col4" >-58.57</td>
#       <td id="T_67114_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_67114_row3_col6" class="data row3 col6" >68</td>
#       <td id="T_67114_row3_col7" class="data row3 col7" >0.35</td>
#       <td id="T_67114_row3_col8" class="data row3 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_67114_row4_col0" class="data row4 col0" >1895</td>
#       <td id="T_67114_row4_col1" class="data row4 col1" >151</td>
#       <td id="T_67114_row4_col2" class="data row4 col2" >43.18</td>
#       <td id="T_67114_row4_col3" class="data row4 col3" >33.76</td>
#       <td id="T_67114_row4_col4" class="data row4 col4" >-58.57</td>
#       <td id="T_67114_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_67114_row4_col6" class="data row4 col6" >68</td>
#       <td id="T_67114_row4_col7" class="data row4 col7" >0.34</td>
#       <td id="T_67114_row4_col8" class="data row4 col8" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Below is the summary of selected matrices difference in transit AM skim

# %%
comparison_excluded = comparison.drop(columns=['Origin', 'Destination'])
desc = comparison_excluded.describe().applymap(lambda x: f"{x:,.2f}").style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'lightblue')]}]  # Custom header style
)
desc
# Out:
# <style type="text/css">
# #T_cbd6b thead th {
#   background-color: lightblue;
# }
# </style>
# <table id="T_cbd6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbd6b_level0_col0" class="col_heading level0 col0" >WALK_PRM_TOTALIVTT__AM</th>
#       <th id="T_cbd6b_level0_col1" class="col_heading level0 col1" >WALK_PRM_LRTIVTT__AM</th>
#       <th id="T_cbd6b_level0_col2" class="col_heading level0 col2" >WALK_PRM_CMRIVTT__AM</th>
#       <th id="T_cbd6b_level0_col3" class="col_heading level0 col3" >WALK_PRM_EXPIVTT__AM</th>
#       <th id="T_cbd6b_level0_col4" class="col_heading level0 col4" >WALK_PRM_BRTIVTT__AM</th>
#       <th id="T_cbd6b_level0_col5" class="col_heading level0 col5" >WALK_LOC_TOTALIVTT__AM</th>
#       <th id="T_cbd6b_level0_col6" class="col_heading level0 col6" >WALK_MIX_TOTALIVTT__AM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbd6b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_cbd6b_row0_col0" class="data row0 col0" >24,472,809.00</td>
#       <td id="T_cbd6b_row0_col1" class="data row0 col1" >24,472,809.00</td>
#       <td id="T_cbd6b_row0_col2" class="data row0 col2" >24,472,809.00</td>
#       <td id="T_cbd6b_row0_col3" class="data row0 col3" >24,472,809.00</td>
#       <td id="T_cbd6b_row0_col4" class="data row0 col4" >24,472,809.00</td>
#       <td id="T_cbd6b_row0_col5" class="data row0 col5" >24,472,809.00</td>
#       <td id="T_cbd6b_row0_col6" class="data row0 col6" >24,472,809.00</td>
#     </tr>
#     <tr>
#       <th id="T_cbd6b_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_cbd6b_row1_col0" class="data row1 col0" >0.01</td>
#       <td id="T_cbd6b_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_cbd6b_row1_col2" class="data row1 col2" >0.01</td>
#       <td id="T_cbd6b_row1_col3" class="data row1 col3" >-0.00</td>
#       <td id="T_cbd6b_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_cbd6b_row1_col5" class="data row1 col5" >0.07</td>
#       <td id="T_cbd6b_row1_col6" class="data row1 col6" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_cbd6b_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_cbd6b_row2_col0" class="data row2 col0" >0.48</td>
#       <td id="T_cbd6b_row2_col1" class="data row2 col1" >0.49</td>
#       <td id="T_cbd6b_row2_col2" class="data row2 col2" >0.56</td>
#       <td id="T_cbd6b_row2_col3" class="data row2 col3" >0.29</td>
#       <td id="T_cbd6b_row2_col4" class="data row2 col4" >0.69</td>
#       <td id="T_cbd6b_row2_col5" class="data row2 col5" >0.40</td>
#       <td id="T_cbd6b_row2_col6" class="data row2 col6" >2.33</td>
#     </tr>
#     <tr>
#       <th id="T_cbd6b_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_cbd6b_row3_col0" class="data row3 col0" >-50.86</td>
#       <td id="T_cbd6b_row3_col1" class="data row3 col1" >-54.96</td>
#       <td id="T_cbd6b_row3_col2" class="data row3 col2" >-59.21</td>
#       <td id="T_cbd6b_row3_col3" class="data row3 col3" >-62.87</td>
#       <td id="T_cbd6b_row3_col4" class="data row3 col4" >-69.54</td>
#       <td id="T_cbd6b_row3_col5" class="data row3 col5" >-40.43</td>
#       <td id="T_cbd6b_row3_col6" class="data row3 col6" >-127.03</td>
#     </tr>
#     <tr>
#       <th id="T_cbd6b_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_cbd6b_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_cbd6b_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_cbd6b_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_cbd6b_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_cbd6b_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_cbd6b_row4_col5" class="data row4 col5" >0.00</td>
#       <td id="T_cbd6b_row4_col6" class="data row4 col6" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cbd6b_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_cbd6b_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_cbd6b_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_cbd6b_row5_col2" class="data row5 col2" >0.00</td>
#       <td id="T_cbd6b_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_cbd6b_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_cbd6b_row5_col5" class="data row5 col5" >0.00</td>
#       <td id="T_cbd6b_row5_col6" class="data row5 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cbd6b_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_cbd6b_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_cbd6b_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_cbd6b_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_cbd6b_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_cbd6b_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_cbd6b_row6_col5" class="data row6 col5" >0.09</td>
#       <td id="T_cbd6b_row6_col6" class="data row6 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cbd6b_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_cbd6b_row7_col0" class="data row7 col0" >43.18</td>
#       <td id="T_cbd6b_row7_col1" class="data row7 col1" >49.24</td>
#       <td id="T_cbd6b_row7_col2" class="data row7 col2" >59.24</td>
#       <td id="T_cbd6b_row7_col3" class="data row7 col3" >77.12</td>
#       <td id="T_cbd6b_row7_col4" class="data row7 col4" >72.90</td>
#       <td id="T_cbd6b_row7_col5" class="data row7 col5" >41.62</td>
#       <td id="T_cbd6b_row7_col6" class="data row7 col6" >144.49</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__AM greater than 50

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__AM']>45].round(2).applymap(lambda x: f"{x:.2f}".rstrip('0').rstrip('.')).style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'lightblue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_56fc4 thead th {
#   background-color: lightblue;
# }
# </style>
# <table id="T_56fc4">
#   <thead>
#     <tr>
#       <th id="T_56fc4_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_56fc4_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_56fc4_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__AM</th>
#       <th id="T_56fc4_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__AM</th>
#       <th id="T_56fc4_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__AM</th>
#       <th id="T_56fc4_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__AM</th>
#       <th id="T_56fc4_level0_col6" class="col_heading level0 col6" >WALK_PRM_BRTIVTT__AM</th>
#       <th id="T_56fc4_level0_col7" class="col_heading level0 col7" >WALK_LOC_TOTALIVTT__AM</th>
#       <th id="T_56fc4_level0_col8" class="col_heading level0 col8" >WALK_MIX_TOTALIVTT__AM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_56fc4_row0_col0" class="data row0 col0" >2538</td>
#       <td id="T_56fc4_row0_col1" class="data row0 col1" >52</td>
#       <td id="T_56fc4_row0_col2" class="data row0 col2" >23.52</td>
#       <td id="T_56fc4_row0_col3" class="data row0 col3" >49.24</td>
#       <td id="T_56fc4_row0_col4" class="data row0 col4" >-59.21</td>
#       <td id="T_56fc4_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_56fc4_row0_col6" class="data row0 col6" >33.49</td>
#       <td id="T_56fc4_row0_col7" class="data row0 col7" >0.38</td>
#       <td id="T_56fc4_row0_col8" class="data row0 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_56fc4_row1_col0" class="data row1 col0" >2547</td>
#       <td id="T_56fc4_row1_col1" class="data row1 col1" >44</td>
#       <td id="T_56fc4_row1_col2" class="data row1 col2" >23.52</td>
#       <td id="T_56fc4_row1_col3" class="data row1 col3" >49.24</td>
#       <td id="T_56fc4_row1_col4" class="data row1 col4" >-59.21</td>
#       <td id="T_56fc4_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_56fc4_row1_col6" class="data row1 col6" >33.49</td>
#       <td id="T_56fc4_row1_col7" class="data row1 col7" >0.38</td>
#       <td id="T_56fc4_row1_col8" class="data row1 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_56fc4_row2_col0" class="data row2 col0" >2600</td>
#       <td id="T_56fc4_row2_col1" class="data row2 col1" >44</td>
#       <td id="T_56fc4_row2_col2" class="data row2 col2" >23.52</td>
#       <td id="T_56fc4_row2_col3" class="data row2 col3" >49.24</td>
#       <td id="T_56fc4_row2_col4" class="data row2 col4" >-59.21</td>
#       <td id="T_56fc4_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_56fc4_row2_col6" class="data row2 col6" >33.49</td>
#       <td id="T_56fc4_row2_col7" class="data row2 col7" >0.38</td>
#       <td id="T_56fc4_row2_col8" class="data row2 col8" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's check the records with difference in WALK_PRM_LRTIVTT__AM less than -50

# %%
comparison.loc[comparison['WALK_PRM_LRTIVTT__AM']<-50].round(2).applymap(lambda x: f"{x:.2f}".rstrip('0').rstrip('.')).style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', 'lightblue')]}]  # Custom header style
).hide(axis = "index")
# Out:
# <style type="text/css">
# #T_6c0ed thead th {
#   background-color: lightblue;
# }
# </style>
# <table id="T_6c0ed">
#   <thead>
#     <tr>
#       <th id="T_6c0ed_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_6c0ed_level0_col1" class="col_heading level0 col1" >Destination</th>
#       <th id="T_6c0ed_level0_col2" class="col_heading level0 col2" >WALK_PRM_TOTALIVTT__AM</th>
#       <th id="T_6c0ed_level0_col3" class="col_heading level0 col3" >WALK_PRM_LRTIVTT__AM</th>
#       <th id="T_6c0ed_level0_col4" class="col_heading level0 col4" >WALK_PRM_CMRIVTT__AM</th>
#       <th id="T_6c0ed_level0_col5" class="col_heading level0 col5" >WALK_PRM_EXPIVTT__AM</th>
#       <th id="T_6c0ed_level0_col6" class="col_heading level0 col6" >WALK_PRM_BRTIVTT__AM</th>
#       <th id="T_6c0ed_level0_col7" class="col_heading level0 col7" >WALK_LOC_TOTALIVTT__AM</th>
#       <th id="T_6c0ed_level0_col8" class="col_heading level0 col8" >WALK_MIX_TOTALIVTT__AM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6c0ed_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_6c0ed_row0_col1" class="data row0 col1" >2364</td>
#       <td id="T_6c0ed_row0_col2" class="data row0 col2" >-10.25</td>
#       <td id="T_6c0ed_row0_col3" class="data row0 col3" >-53.38</td>
#       <td id="T_6c0ed_row0_col4" class="data row0 col4" >59.24</td>
#       <td id="T_6c0ed_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_6c0ed_row0_col6" class="data row0 col6" >-16.1</td>
#       <td id="T_6c0ed_row0_col7" class="data row0 col7" >-0.1</td>
#       <td id="T_6c0ed_row0_col8" class="data row0 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6c0ed_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_6c0ed_row1_col1" class="data row1 col1" >2398</td>
#       <td id="T_6c0ed_row1_col2" class="data row1 col2" >-10.25</td>
#       <td id="T_6c0ed_row1_col3" class="data row1 col3" >-53.38</td>
#       <td id="T_6c0ed_row1_col4" class="data row1 col4" >59.24</td>
#       <td id="T_6c0ed_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_6c0ed_row1_col6" class="data row1 col6" >-16.1</td>
#       <td id="T_6c0ed_row1_col7" class="data row1 col7" >-0.1</td>
#       <td id="T_6c0ed_row1_col8" class="data row1 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6c0ed_row2_col0" class="data row2 col0" >24</td>
#       <td id="T_6c0ed_row2_col1" class="data row2 col1" >2420</td>
#       <td id="T_6c0ed_row2_col2" class="data row2 col2" >-10.25</td>
#       <td id="T_6c0ed_row2_col3" class="data row2 col3" >-53.38</td>
#       <td id="T_6c0ed_row2_col4" class="data row2 col4" >59.24</td>
#       <td id="T_6c0ed_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_6c0ed_row2_col6" class="data row2 col6" >-16.1</td>
#       <td id="T_6c0ed_row2_col7" class="data row2 col7" >-0.1</td>
#       <td id="T_6c0ed_row2_col8" class="data row2 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6c0ed_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_6c0ed_row3_col1" class="data row3 col1" >2436</td>
#       <td id="T_6c0ed_row3_col2" class="data row3 col2" >-10.25</td>
#       <td id="T_6c0ed_row3_col3" class="data row3 col3" >-53.38</td>
#       <td id="T_6c0ed_row3_col4" class="data row3 col4" >59.24</td>
#       <td id="T_6c0ed_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_6c0ed_row3_col6" class="data row3 col6" >-16.1</td>
#       <td id="T_6c0ed_row3_col7" class="data row3 col7" >-0.1</td>
#       <td id="T_6c0ed_row3_col8" class="data row3 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6c0ed_row4_col0" class="data row4 col0" >24</td>
#       <td id="T_6c0ed_row4_col1" class="data row4 col1" >2526</td>
#       <td id="T_6c0ed_row4_col2" class="data row4 col2" >-10.25</td>
#       <td id="T_6c0ed_row4_col3" class="data row4 col3" >-53.38</td>
#       <td id="T_6c0ed_row4_col4" class="data row4 col4" >59.24</td>
#       <td id="T_6c0ed_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_6c0ed_row4_col6" class="data row4 col6" >-16.1</td>
#       <td id="T_6c0ed_row4_col7" class="data row4 col7" >-0.1</td>
#       <td id="T_6c0ed_row4_col8" class="data row4 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6c0ed_row5_col0" class="data row5 col0" >3186</td>
#       <td id="T_6c0ed_row5_col1" class="data row5 col1" >1291</td>
#       <td id="T_6c0ed_row5_col2" class="data row5 col2" >2.2</td>
#       <td id="T_6c0ed_row5_col3" class="data row5 col3" >-54.96</td>
#       <td id="T_6c0ed_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_6c0ed_row5_col5" class="data row5 col5" >57.15</td>
#       <td id="T_6c0ed_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_6c0ed_row5_col7" class="data row5 col7" >0.44</td>
#       <td id="T_6c0ed_row5_col8" class="data row5 col8" >0</td>
#     </tr>
#   </tbody>
# </table>
